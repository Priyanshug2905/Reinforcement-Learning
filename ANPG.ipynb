# %%
# !apt-get install ffmpeg freeglut3-dev xvfb  # For visualization
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# !pip install tensorboard
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import gym
from torch.distributions import Categorical
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   freeglut3 libegl-dev libfontenc1 libgl-dev libgl1-mesa-dev libgles-dev libgles1 libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libice-dev libopengl-dev libsm-dev
#   libxfont2 libxkbfile1 libxt-dev x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# Suggested packages:
#   libice-doc libsm-doc libxt-doc
# The following NEW packages will be installed:
#   freeglut3 freeglut3-dev libegl-dev libfontenc1 libgl-dev libgl1-mesa-dev libgles-dev libgles1
#   libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libice-dev libopengl-dev
#   libsm-dev libxfont2 libxkbfile1 libxt-dev x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xvfb
# 0 upgraded, 25 newly installed, 0 to remove and 49 not upgraded.
# Need to get 9,075 kB of archives.
# After this operation, 18.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [6,842 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3-dev amd64 2.8.1-6 [126 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.11 [28.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.11 [863 kB]
# Fetched 9,075 kB in 0s (30.6 MB/s)
# Selecting previously unselected package freeglut3:amd64.
# (Reading database ... 123620 files and directories currently installed.)
# Preparing to unpack .../00-freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../01-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../02-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../03-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../04-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../05-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../06-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../07-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../08-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../09-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../10-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../11-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../12-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../13-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../14-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../15-freeglut3-dev_2.8.1-6_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-6) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../16-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../17-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../18-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../19-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../20-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../21-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../22-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../23-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.11_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../24-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.11_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.11) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up freeglut3-dev:amd64 (2.8.1-6) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Collecting stable-baselines3>=2.0.0a4 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading stable_baselines3-2.4.0a7-py3-none-any.whl.metadata (5.1 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.4.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.66.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (13.8.1)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (10.4.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.32.3)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 17.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.18.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (6.4.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a4) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Downloading stable_baselines3-2.4.0a7-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.9/182.9 kB 14.3 MB/s eta 0:00:00
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 32.6 MB/s eta 0:00:00
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 51.3 MB/s eta 0:00:00
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446661 sha256=017b4668f3ad215005c63c0a6f07eea0c2cde255c9e8bf4eac3a9023514502b3
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, gymnasium, ale-py, shimmy, AutoROM.accept-rom-license, autorom, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.29.1 shimmy-1.3.0 stable-baselines3-2.4.0a7
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)

# %%
# Create the CartPole-v1 environment
env = gym.make('CartPole-v1')

# Hyperparameters
gamma = 0.99
lr = 1e-4  # Try lowering the learning rate
H = 20  # Number of inner loops
K = 500  # Reduce the outer loops for testing
eta = 0.009  # Policy update rate
alpha = 0.9
beta = 0.9
xi = 0.9
entropy_weight = 0.01  # Entropy regularization

# Policy Network
class PolicyNetwork(nn.Module):
    def __init__(self):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(4, 128)  # Input is 4-dimensional for CartPole
        self.fc2 = nn.Linear(128, 2)  # Output is 2-dimensional (left/right)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return torch.softmax(x, dim=-1)

# Accelerated Natural Policy Gradient (ANPG)
class ANPG:
    def __init__(self, env, policy_network):
        self.env = env
        self.policy_network = policy_network
        self.optimizer = optim.Adam(self.policy_network.parameters(), lr=lr)

    def select_action(self, state):
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)  # Shape: [1, 4]
        probs = self.policy_network(state)
        dist = Categorical(probs)
        action = dist.sample()
        return action.item(), dist.log_prob(action), probs

    def compute_returns(self, rewards):
        R = 0
        returns = []
        for r in rewards[::-1]:
            R = r + gamma * R
            returns.insert(0, R)
        return returns

    def train(self):
        for k in range(K):
            state = self.env.reset()  # Reset environment and get initial state
            x0 = [torch.zeros_like(param) for param in self.policy_network.parameters()]  # Initialize x0
            v0 = [torch.zeros_like(param) for param in self.policy_network.parameters()]  # Initialize v0

            # Outer loop - K iterations
            for h in range(H):
                log_probs = []
                rewards = []
                y_h = [alpha * x0_ + (1 - alpha) * v0_ for x0_, v0_ in zip(x0, v0)]  # Layer-wise update for y_h

                # Inner loop - Sampling trajectories
                for step in range(200):
                    action, log_prob, probs = self.select_action(state)
                    next_state, reward, done, _ = self.env.step(action)

                    # Debug prints
                    #print(f"Step: {step}, Action: {action}, Reward: {reward}, Done: {done}, Probs: {probs}")

                    log_probs.append(log_prob)
                    rewards.append(reward)
                    state = next_state

                    if done:
                        break

                # Compute returns and policy loss
                returns = self.compute_returns(rewards)
                returns = torch.tensor(returns, dtype=torch.float32)  # Ensure it's a tensor
                log_probs = torch.stack(log_probs)

                policy_loss = -log_probs * (returns - returns.mean())  # Policy gradient loss
                policy_loss = policy_loss.sum()

                # Entropy regularization to encourage exploration
                entropy = -torch.sum(probs * torch.log(probs), dim=-1)
                policy_loss -= entropy_weight * entropy.sum()

                self.optimizer.zero_grad()
                grad_logp = torch.autograd.grad(policy_loss, self.policy_network.parameters(), create_graph=True, retain_graph=True)
                policy_loss.backward()
                self.optimizer.step()

                # Accelerated Gradient Steps (layer-wise)
                with torch.no_grad():
                    x_h = [y_h_ - eta * g for y_h_, g in zip(y_h, grad_logp)]  # Update x_h layer-wise
                    z_h = [beta * y_h_ + (1 - beta) * v0_ for y_h_, v0_ in zip(y_h, v0)]
                    v_h = [z_h_ - xi * g for z_h_, g in zip(z_h, grad_logp)]

                # Update x0 for the next inner loop iteration
                x0 = x_h

            # Tail averaging (layer-wise)
            omega_k = [2 / H * sum(x_h_) for x_h_ in x0]  # Calculate omega_k for each layer

            # Update policy parameters (layer-wise)
            for param, omega in zip(self.policy_network.parameters(), omega_k):
                param.data -= eta * omega

            # Logging
            print(f'Episode {k}: Reward Sum {sum(rewards)}')

# Instantiate policy network and ANPG algorithm
policy_net = PolicyNetwork()
anpg = ANPG(env, policy_net)

# Training ANPG
anpg.train()

env.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# Episode 0: Reward Sum 0.0
# Episode 1: Reward Sum 0.0
# Episode 2: Reward Sum 0.0
# Episode 3: Reward Sum 0.0
# Episode 4: Reward Sum 0.0
# Episode 5: Reward Sum 0.0
# Episode 6: Reward Sum 0.0
# Episode 7: Reward Sum 0.0
# Episode 8: Reward Sum 0.0
# Episode 9: Reward Sum 0.0
# Episode 10: Reward Sum 0.0
# Episode 11: Reward Sum 0.0
# Episode 12: Reward Sum 0.0
# Episode 13: Reward Sum 0.0
# Episode 14: Reward Sum 0.0
# Episode 15: Reward Sum 0.0
# Episode 16: Reward Sum 0.0
# Episode 17: Reward Sum 0.0
# Episode 18: Reward Sum 0.0
# Episode 19: Reward Sum 0.0
# Episode 20: Reward Sum 0.0
# Episode 21: Reward Sum 0.0
# Episode 22: Reward Sum 0.0
# Episode 23: Reward Sum 0.0
# Episode 24: Reward Sum 0.0
# Episode 25: Reward Sum 0.0
# Episode 26: Reward Sum 0.0
# Episode 27: Reward Sum 0.0
# Episode 28: Reward Sum 0.0
# Episode 29: Reward Sum 0.0
# Episode 30: Reward Sum 0.0
# Episode 31: Reward Sum 0.0
# Episode 32: Reward Sum 0.0
# Episode 33: Reward Sum 0.0
# Episode 34: Reward Sum 0.0
# Episode 35: Reward Sum 0.0
# Episode 36: Reward Sum 0.0
# Episode 37: Reward Sum 0.0
# Episode 38: Reward Sum 0.0
# Episode 39: Reward Sum 0.0
# Episode 40: Reward Sum 0.0
# Episode 41: Reward Sum 0.0
# Episode 42: Reward Sum 0.0
# Episode 43: Reward Sum 0.0
# Episode 44: Reward Sum 0.0
# Episode 45: Reward Sum 0.0
# Episode 46: Reward Sum 0.0
# Episode 47: Reward Sum 0.0
# Episode 48: Reward Sum 0.0
# Episode 49: Reward Sum 0.0
# Episode 50: Reward Sum 0.0
# Episode 51: Reward Sum 0.0
# Episode 52: Reward Sum 0.0
# Episode 53: Reward Sum 0.0
# Episode 54: Reward Sum 0.0
# Episode 55: Reward Sum 0.0
# Episode 56: Reward Sum 0.0
# Episode 57: Reward Sum 0.0
# Episode 58: Reward Sum 0.0
# Episode 59: Reward Sum 0.0
# Episode 60: Reward Sum 0.0
# Episode 61: Reward Sum 0.0
# Episode 62: Reward Sum 0.0
# Episode 63: Reward Sum 0.0
# Episode 64: Reward Sum 0.0
# Episode 65: Reward Sum 0.0
# Episode 66: Reward Sum 0.0
# Episode 67: Reward Sum 0.0
# Episode 68: Reward Sum 0.0
# Episode 69: Reward Sum 0.0
# Episode 70: Reward Sum 0.0
# Episode 71: Reward Sum 0.0
# Episode 72: Reward Sum 0.0
# Episode 73: Reward Sum 0.0
# Episode 74: Reward Sum 0.0
# Episode 75: Reward Sum 0.0
# Episode 76: Reward Sum 0.0
# Episode 77: Reward Sum 0.0
# Episode 78: Reward Sum 0.0
# Episode 79: Reward Sum 0.0
# Episode 80: Reward Sum 0.0
# Episode 81: Reward Sum 0.0
# Episode 82: Reward Sum 0.0
# Episode 83: Reward Sum 0.0
# Episode 84: Reward Sum 0.0
# Episode 85: Reward Sum 0.0
# Episode 86: Reward Sum 0.0
# Episode 87: Reward Sum 0.0
# Episode 88: Reward Sum 0.0
# Episode 89: Reward Sum 0.0
# Episode 90: Reward Sum 0.0
# Episode 91: Reward Sum 0.0
# Episode 92: Reward Sum 0.0
# Episode 93: Reward Sum 0.0
# Episode 94: Reward Sum 0.0
# Episode 95: Reward Sum 0.0
# Episode 96: Reward Sum 0.0
# Episode 97: Reward Sum 0.0
# Episode 98: Reward Sum 0.0
# Episode 99: Reward Sum 0.0
# Episode 100: Reward Sum 0.0
# Episode 101: Reward Sum 0.0
# Episode 102: Reward Sum 0.0
# Episode 103: Reward Sum 0.0
# Episode 104: Reward Sum 0.0
# Episode 105: Reward Sum 0.0
# Episode 106: Reward Sum 0.0
# Episode 107: Reward Sum 0.0
# Episode 108: Reward Sum 0.0
# Episode 109: Reward Sum 0.0
# Episode 110: Reward Sum 0.0
# Episode 111: Reward Sum 0.0
# Episode 112: Reward Sum 0.0
# Episode 113: Reward Sum 0.0
# Episode 114: Reward Sum 0.0
# Episode 115: Reward Sum 0.0
# Episode 116: Reward Sum 0.0
# Episode 117: Reward Sum 0.0
# Episode 118: Reward Sum 0.0
# Episode 119: Reward Sum 0.0
# Episode 120: Reward Sum 0.0
# Episode 121: Reward Sum 0.0
# Episode 122: Reward Sum 0.0
# Episode 123: Reward Sum 0.0
# Episode 124: Reward Sum 0.0
# Episode 125: Reward Sum 0.0
# Episode 126: Reward Sum 0.0
# Episode 127: Reward Sum 0.0
# Episode 128: Reward Sum 0.0
# Episode 129: Reward Sum 0.0
# Episode 130: Reward Sum 0.0
# Episode 131: Reward Sum 0.0
# Episode 132: Reward Sum 0.0
# Episode 133: Reward Sum 0.0
# Episode 134: Reward Sum 0.0
# Episode 135: Reward Sum 0.0
# Episode 136: Reward Sum 0.0
# Episode 137: Reward Sum 0.0
# Episode 138: Reward Sum 0.0
# Episode 139: Reward Sum 0.0
# Episode 140: Reward Sum 0.0
# Episode 141: Reward Sum 0.0
# Episode 142: Reward Sum 0.0
# Episode 143: Reward Sum 0.0
# Episode 144: Reward Sum 0.0
# Episode 145: Reward Sum 0.0
# Episode 146: Reward Sum 0.0
# Episode 147: Reward Sum 0.0
# Episode 148: Reward Sum 0.0
# Episode 149: Reward Sum 0.0
# Episode 150: Reward Sum 0.0
# Episode 151: Reward Sum 0.0
# Episode 152: Reward Sum 0.0
# Episode 153: Reward Sum 0.0
# Episode 154: Reward Sum 0.0
# Episode 155: Reward Sum 0.0
# Episode 156: Reward Sum 0.0
# Episode 157: Reward Sum 0.0
# Episode 158: Reward Sum 0.0
# Episode 159: Reward Sum 0.0
# Episode 160: Reward Sum 0.0
# Episode 161: Reward Sum 0.0
# Episode 162: Reward Sum 0.0
# Episode 163: Reward Sum 0.0
# Episode 164: Reward Sum 0.0
# Episode 165: Reward Sum 0.0
# Episode 166: Reward Sum 0.0
# Episode 167: Reward Sum 0.0
# Episode 168: Reward Sum 0.0
# Episode 169: Reward Sum 0.0
# Episode 170: Reward Sum 0.0
# Episode 171: Reward Sum 0.0
# Episode 172: Reward Sum 0.0
# Episode 173: Reward Sum 0.0
# Episode 174: Reward Sum 0.0
# Episode 175: Reward Sum 0.0
# Episode 176: Reward Sum 0.0
# Episode 177: Reward Sum 0.0
# Episode 178: Reward Sum 0.0
# Episode 179: Reward Sum 0.0
# Episode 180: Reward Sum 0.0
# Episode 181: Reward Sum 0.0
# Episode 182: Reward Sum 0.0
# Episode 183: Reward Sum 0.0
# Episode 184: Reward Sum 0.0
# Episode 185: Reward Sum 0.0
# Episode 186: Reward Sum 0.0
# Episode 187: Reward Sum 0.0
# Episode 188: Reward Sum 0.0
# Episode 189: Reward Sum 0.0
# Episode 190: Reward Sum 0.0
# Episode 191: Reward Sum 0.0
# Episode 192: Reward Sum 0.0
# Episode 193: Reward Sum 0.0
# Episode 194: Reward Sum 0.0
# Episode 195: Reward Sum 0.0
# Episode 196: Reward Sum 0.0
# Episode 197: Reward Sum 0.0
# Episode 198: Reward Sum 0.0
# Episode 199: Reward Sum 0.0
# Episode 200: Reward Sum 0.0
# Episode 201: Reward Sum 0.0
# Episode 202: Reward Sum 0.0
# Episode 203: Reward Sum 0.0
# Episode 204: Reward Sum 0.0
# Episode 205: Reward Sum 0.0
# Episode 206: Reward Sum 0.0
# Episode 207: Reward Sum 0.0
# Episode 208: Reward Sum 0.0
# Episode 209: Reward Sum 0.0
# Episode 210: Reward Sum 0.0
# Episode 211: Reward Sum 0.0
# Episode 212: Reward Sum 0.0
# Episode 213: Reward Sum 0.0
# Episode 214: Reward Sum 0.0
# Episode 215: Reward Sum 0.0
# Episode 216: Reward Sum 0.0
# Episode 217: Reward Sum 0.0
# Episode 218: Reward Sum 0.0
# Episode 219: Reward Sum 0.0
# Episode 220: Reward Sum 0.0
# Episode 221: Reward Sum 0.0
# Episode 222: Reward Sum 0.0
# Episode 223: Reward Sum 0.0
# Episode 224: Reward Sum 0.0
# Episode 225: Reward Sum 0.0
# Episode 226: Reward Sum 0.0
# Episode 227: Reward Sum 0.0
# Episode 228: Reward Sum 0.0
# Episode 229: Reward Sum 0.0
# Episode 230: Reward Sum 0.0
# Episode 231: Reward Sum 0.0
# Episode 232: Reward Sum 0.0
# Episode 233: Reward Sum 0.0
# Episode 234: Reward Sum 0.0
# Episode 235: Reward Sum 0.0
# Episode 236: Reward Sum 0.0
# Episode 237: Reward Sum 0.0
# Episode 238: Reward Sum 0.0
# Episode 239: Reward Sum 0.0
# Episode 240: Reward Sum 0.0
# Episode 241: Reward Sum 0.0
# Episode 242: Reward Sum 0.0
# Episode 243: Reward Sum 0.0
# Episode 244: Reward Sum 0.0
# Episode 245: Reward Sum 0.0
# Episode 246: Reward Sum 0.0
# Episode 247: Reward Sum 0.0
# Episode 248: Reward Sum 0.0
# Episode 249: Reward Sum 0.0
# Episode 250: Reward Sum 0.0
# Episode 251: Reward Sum 0.0
# Episode 252: Reward Sum 0.0
# Episode 253: Reward Sum 0.0
# Episode 254: Reward Sum 0.0
# Episode 255: Reward Sum 0.0
# Episode 256: Reward Sum 0.0
# Episode 257: Reward Sum 0.0
# Episode 258: Reward Sum 0.0
# Episode 259: Reward Sum 0.0
# Episode 260: Reward Sum 0.0
# Episode 261: Reward Sum 0.0
# Episode 262: Reward Sum 0.0
# Episode 263: Reward Sum 0.0
# Episode 264: Reward Sum 0.0
# Episode 265: Reward Sum 0.0
# Episode 266: Reward Sum 0.0
# Episode 267: Reward Sum 0.0
# Episode 268: Reward Sum 0.0
# Episode 269: Reward Sum 0.0
# Episode 270: Reward Sum 0.0
# Episode 271: Reward Sum 0.0
# Episode 272: Reward Sum 0.0
# Episode 273: Reward Sum 0.0
# Episode 274: Reward Sum 0.0
# Episode 275: Reward Sum 0.0
# Episode 276: Reward Sum 0.0
# Episode 277: Reward Sum 0.0
# Episode 278: Reward Sum 0.0
# Episode 279: Reward Sum 0.0
# Episode 280: Reward Sum 0.0
# Episode 281: Reward Sum 0.0
# Episode 282: Reward Sum 0.0
# Episode 283: Reward Sum 0.0
# Episode 284: Reward Sum 0.0
# Episode 285: Reward Sum 0.0
# Episode 286: Reward Sum 0.0
# Episode 287: Reward Sum 0.0
# Episode 288: Reward Sum 0.0
# Episode 289: Reward Sum 0.0
# Episode 290: Reward Sum 0.0
# Episode 291: Reward Sum 0.0
# Episode 292: Reward Sum 0.0
# Episode 293: Reward Sum 0.0
# Episode 294: Reward Sum 0.0
# Episode 295: Reward Sum 0.0
# Episode 296: Reward Sum 0.0
# Episode 297: Reward Sum 0.0
# Episode 298: Reward Sum 0.0
# Episode 299: Reward Sum 0.0
# Episode 300: Reward Sum 0.0
# Episode 301: Reward Sum 0.0
# Episode 302: Reward Sum 0.0
# Episode 303: Reward Sum 0.0
# Episode 304: Reward Sum 0.0
# Episode 305: Reward Sum 0.0
# Episode 306: Reward Sum 0.0
# Episode 307: Reward Sum 0.0
# Episode 308: Reward Sum 0.0
# Episode 309: Reward Sum 0.0
# Episode 310: Reward Sum 0.0
# Episode 311: Reward Sum 0.0
# Episode 312: Reward Sum 0.0
# Episode 313: Reward Sum 0.0
# Episode 314: Reward Sum 0.0
# Episode 315: Reward Sum 0.0
# Episode 316: Reward Sum 0.0
# Episode 317: Reward Sum 0.0
# Episode 318: Reward Sum 0.0
# Episode 319: Reward Sum 0.0
# Episode 320: Reward Sum 0.0
# Episode 321: Reward Sum 0.0
# Episode 322: Reward Sum 0.0
# Episode 323: Reward Sum 0.0
# Episode 324: Reward Sum 0.0
# Episode 325: Reward Sum 0.0
# Episode 326: Reward Sum 0.0
# Episode 327: Reward Sum 0.0
# Episode 328: Reward Sum 0.0
# Episode 329: Reward Sum 0.0
# Episode 330: Reward Sum 0.0
# Episode 331: Reward Sum 0.0
# Episode 332: Reward Sum 0.0
# Episode 333: Reward Sum 0.0
# Episode 334: Reward Sum 0.0
# Episode 335: Reward Sum 0.0
# Episode 336: Reward Sum 0.0
# Episode 337: Reward Sum 0.0
# Episode 338: Reward Sum 0.0
# Episode 339: Reward Sum 0.0
# Episode 340: Reward Sum 0.0
# Episode 341: Reward Sum 0.0
# Episode 342: Reward Sum 0.0
# Episode 343: Reward Sum 0.0
# Episode 344: Reward Sum 0.0
# Episode 345: Reward Sum 0.0
# Episode 346: Reward Sum 0.0
# Episode 347: Reward Sum 0.0
# Episode 348: Reward Sum 0.0
# Episode 349: Reward Sum 0.0
# Episode 350: Reward Sum 0.0
# Episode 351: Reward Sum 0.0
# Episode 352: Reward Sum 0.0
# Episode 353: Reward Sum 0.0
# Episode 354: Reward Sum 0.0
# Episode 355: Reward Sum 0.0
# Episode 356: Reward Sum 0.0
# Episode 357: Reward Sum 0.0
# Episode 358: Reward Sum 0.0
# Episode 359: Reward Sum 0.0
# Episode 360: Reward Sum 0.0
# Episode 361: Reward Sum 0.0
# Episode 362: Reward Sum 0.0
# Episode 363: Reward Sum 0.0
# Episode 364: Reward Sum 0.0
# Episode 365: Reward Sum 0.0
# Episode 366: Reward Sum 0.0
# Episode 367: Reward Sum 0.0
# Episode 368: Reward Sum 0.0
# Episode 369: Reward Sum 0.0
# Episode 370: Reward Sum 0.0
# Episode 371: Reward Sum 0.0
# Episode 372: Reward Sum 0.0
# Episode 373: Reward Sum 0.0
# Episode 374: Reward Sum 0.0
# Episode 375: Reward Sum 0.0
# Episode 376: Reward Sum 0.0
# Episode 377: Reward Sum 0.0
# Episode 378: Reward Sum 0.0
# Episode 379: Reward Sum 0.0
# Episode 380: Reward Sum 0.0
# Episode 381: Reward Sum 0.0
# Episode 382: Reward Sum 0.0
# Episode 383: Reward Sum 0.0
# Episode 384: Reward Sum 0.0
# Episode 385: Reward Sum 0.0
# Episode 386: Reward Sum 0.0
# Episode 387: Reward Sum 0.0
# Episode 388: Reward Sum 0.0
# Episode 389: Reward Sum 0.0
# Episode 390: Reward Sum 0.0
# Episode 391: Reward Sum 0.0
# Episode 392: Reward Sum 0.0
# Episode 393: Reward Sum 0.0
# Episode 394: Reward Sum 0.0
# Episode 395: Reward Sum 0.0
# Episode 396: Reward Sum 0.0
# Episode 397: Reward Sum 0.0
# Episode 398: Reward Sum 0.0
# Episode 399: Reward Sum 0.0
# Episode 400: Reward Sum 0.0
# Episode 401: Reward Sum 0.0
# Episode 402: Reward Sum 0.0
# Episode 403: Reward Sum 0.0
# Episode 404: Reward Sum 0.0
# Episode 405: Reward Sum 0.0
# Episode 406: Reward Sum 0.0
# Episode 407: Reward Sum 0.0
# Episode 408: Reward Sum 0.0
# Episode 409: Reward Sum 0.0
# Episode 410: Reward Sum 0.0
# Episode 411: Reward Sum 0.0
# Episode 412: Reward Sum 0.0
# Episode 413: Reward Sum 0.0
# Episode 414: Reward Sum 0.0
# Episode 415: Reward Sum 0.0
# Episode 416: Reward Sum 0.0
# Episode 417: Reward Sum 0.0
# Episode 418: Reward Sum 0.0
# Episode 419: Reward Sum 0.0
# Episode 420: Reward Sum 0.0
# Episode 421: Reward Sum 0.0
# Episode 422: Reward Sum 0.0
# Episode 423: Reward Sum 0.0
# Episode 424: Reward Sum 0.0
# Episode 425: Reward Sum 0.0
# Episode 426: Reward Sum 0.0
# Episode 427: Reward Sum 0.0
# Episode 428: Reward Sum 0.0
# Episode 429: Reward Sum 0.0
# Episode 430: Reward Sum 0.0
# Episode 431: Reward Sum 0.0
# Episode 432: Reward Sum 0.0
# Episode 433: Reward Sum 0.0
# Episode 434: Reward Sum 0.0
# Episode 435: Reward Sum 0.0
# Episode 436: Reward Sum 0.0
# Episode 437: Reward Sum 0.0
# Episode 438: Reward Sum 0.0
# Episode 439: Reward Sum 0.0
# Episode 440: Reward Sum 0.0
# Episode 441: Reward Sum 0.0
# Episode 442: Reward Sum 0.0
# Episode 443: Reward Sum 0.0
# Episode 444: Reward Sum 0.0
# Episode 445: Reward Sum 0.0
# Episode 446: Reward Sum 0.0
# Episode 447: Reward Sum 0.0
# Episode 448: Reward Sum 0.0
# Episode 449: Reward Sum 0.0
# Episode 450: Reward Sum 0.0
# Episode 451: Reward Sum 0.0
# Episode 452: Reward Sum 0.0
# Episode 453: Reward Sum 0.0
# Episode 454: Reward Sum 0.0
# Episode 455: Reward Sum 0.0
# Episode 456: Reward Sum 0.0
# Episode 457: Reward Sum 0.0
# Episode 458: Reward Sum 0.0
# Episode 459: Reward Sum 0.0
# Episode 460: Reward Sum 0.0
# Episode 461: Reward Sum 0.0
# Episode 462: Reward Sum 0.0
# Episode 463: Reward Sum 0.0
# Episode 464: Reward Sum 0.0
# Episode 465: Reward Sum 0.0
# Episode 466: Reward Sum 0.0
# Episode 467: Reward Sum 0.0
# Episode 468: Reward Sum 0.0
# Episode 469: Reward Sum 0.0
# Episode 470: Reward Sum 0.0
# Episode 471: Reward Sum 0.0
# Episode 472: Reward Sum 0.0
# Episode 473: Reward Sum 0.0
# Episode 474: Reward Sum 0.0
# Episode 475: Reward Sum 0.0
# Episode 476: Reward Sum 0.0
# Episode 477: Reward Sum 0.0
# Episode 478: Reward Sum 0.0
# Episode 479: Reward Sum 0.0
# Episode 480: Reward Sum 0.0
# Episode 481: Reward Sum 0.0
# Episode 482: Reward Sum 0.0
# Episode 483: Reward Sum 0.0
# Episode 484: Reward Sum 0.0
# Episode 485: Reward Sum 0.0
# Episode 486: Reward Sum 0.0
# Episode 487: Reward Sum 0.0
# Episode 488: Reward Sum 0.0
# Episode 489: Reward Sum 0.0
# Episode 490: Reward Sum 0.0
# Episode 491: Reward Sum 0.0
# Episode 492: Reward Sum 0.0
# Episode 493: Reward Sum 0.0
# Episode 494: Reward Sum 0.0
# Episode 495: Reward Sum 0.0
# Episode 496: Reward Sum 0.0
# Episode 497: Reward Sum 0.0
# Episode 498: Reward Sum 0.0
# Episode 499: Reward Sum 0.0
